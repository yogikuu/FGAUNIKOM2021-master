# %% [markdown]
# # Visualisasi Data di Python
#
# Setelah mempelajari matplotlib, maka kita bisa memvisualisasikan data di Python. Secara umum bentuk visualisasi yang bisa digunakan terbagi menjadi dua, yaitu:
#
# 1. Visualisasi variabel
# 2. Visualisasi statistik
#
# Bentuk visualisasi variabel terdiri dari:
#
# 1. Pie Chart
# 2. Bar Chart
# 3. Line Graphs
# 4. Scatter Plot
# 5. Heatmap
#
# Sementara bentuk visualisasi statistik terdiri dari:
#
# 1. Histogram
# 2. Correlation
# 3. Descriptive Statistik
# 4. Grouping (Pivot)
# 5. ANOVA
#
# Selain bentuk visualisasi tersebut, masih ada beberapa jenis visualisasi lain yang bisa digunakan. Akan tetapi pada pembahasan kali ini, kita akan fokus ke pembahasan ke bentuk visualisasi tersebut. Memilih bentuk visualisasi tentunya bukan hal yang bisa dilakukan tanpa analisis terlebih dahulu. Setiap bentuk visualisasi data hanya cocok untuk menggambarkan suatu jenis informasi yang mau didapatkan. Berikut adalah salah satu panduan dalam memilih bentuk visualisasi data yang baik:
#
# ![Panduan pemilihan visualisasi data](https://drive.google.com/uc?export=view&id=1voK62CPfMZtl3E4uxOnED9LX4tkdBjw3)
#
# Mari kita mulai pembahasan tentang bentuk-bentuk visualisasi data umum. Jalankan perintah berikut untuk Jupyter Notebook:

# %%
# %matplotlib inline

# %% [markdown]
# # Jenis-Jenis Data
#
# Sebelum memvisualisasikan data, ada baiknya kita mengetahui terlebih dahulu tentang jenis data. Jenis data akan menentukan bentuk visualisasi mana yang lebih tepat untuk digunakan. Secara umum data terbagi menjadi dua, yaitu data kualitatif dan kuantitatif. Pembagian jenis data dapat dilihat pada gambar berikut:
#
# <img src = "https://www.qualitydigest.com/IQedit/Images/Articles_and_Columns/2020/06_June-2020/Data/working3_clip_image002_0000.png" alt = "Jenis-Jenis Data">

# %% [markdown]
# # Visualisasi Pie Chart
#
# (Dokumentasi lengkap di https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.axes.Axes.pie.html)
#
# Pie chart cocok digunakan untuk menampilkan komposisi antar kategori yang bersifat statis terhadap jumlah keseluruhan data. Visualisasi ini akan optimal apabila jumlah kategori tidak terlalu banyak. Mari kita coba untuk membuat pie chart menggunakan data berikut:
#
# <b>Data Penggemar Buah Tropis</b>
#
# 1. Nanas: 100 orang
# 2. Durian: 1000 orang
# 3. Rambutan: 300 orang
# 4. Manggis: 900 orang
# 5. Melon: 700 orang

# %%
import matplotlib.pyplot as plt 

buah = ['Nanas', 'Durian', 'Rambutan', 'Manggis', 'Melon']
penggemar = [100, 1000, 300, 900, 700] 
plt.pie(penggemar, labels=buah) 

plt.show()

# %% [markdown]
# ><b>Catatan:</b> Kita bisa menggunakan list, tuple, atau numpy array sebagai parameter yang mau dimunculkan pada pie chart
#
# Kalau kita lihat bentuk visualisasi belum optimal dalam menunjukkan data. Sebagai contoh, porsi antara Durian dengan Manggis hampir serupa sehingga pembaca data akan kebingungan dalam menentukan mana yang lebih dominan. Kita bisa menambahkan parameter ``autopct`` (autopercent) untuk memberikan persentase kepada pice chart tersebut. Berikut kode programnya:

# %%
plt.pie(
    penggemar, 
    labels=buah, 
    autopct= '%1.1f%%'
)

plt.show()

# %% [markdown]
# Kita juga bisa memberikan warna custom pada setiap elemen data di dalam pie chart agar lebih presentatif. Sebagi contoh kita berikan warna merah pada rambutan dan kuning pada Durian. Tambahkan parameter colors untuk mengkustom warna pada pie chart. Berikut contohnya:

# %%
warna = ['#E8B824', '#EFD298', '#E54A48','#F2A2A9', '#758D20']

plt.pie(
    penggemar, 
    labels=buah, 
    autopct= '%1.1f%%',
    colors = warna
)

plt.show()

# %% [markdown]
# Apabila kita ingin mengekspos salah satu elemen data pada pie chart, kita bisa menggunakan parameter ``explode``. Sebagai contoh kita mau mengeskpos buah Manggis dalam visualisasi data yang sudah dibuat. Berikut kode programnya:

# %%
buah_expose = [0, 0, 0, 0.2, 0]

plt.pie(
    penggemar, 
    labels=buah, 
    autopct= '%1.1f%%',
    colors = warna,
    explode = buah_expose
)

plt.show()

# %% [markdown]
# Sedikit sentuhan terakhir, kita bisa mempercantik pie chart dengan memberikan efek shadow agar terlihat tiga dimensi. Untuk melakukan hal tersebut, kita bisa menambahkan parameter ``shadow = True``. Berikut contoh penggunaannya:

# %%
plt.pie(
    penggemar, 
    labels=buah, 
    autopct= '%1.1f%%',
    colors = warna,
    explode = buah_expose,
    shadow = True
)

plt.show()

# %% [markdown]
# Jangan lupa juga untuk memberikan judul pada diagram pie chart yang sudah dibuat agar pembacanya lebih jelas dalam menginterpretasikan maknanya. Berikut kode programnya:

# %%
plt.title('Buah Tropis Favorit')

plt.pie(
    penggemar, 
    labels=buah, 
    autopct= '%1.1f%%',
    colors = warna,
    explode = buah_expose,
    shadow = True
)

plt.show()

# %% [markdown]
# # Diagram Batang
#
# Visualisasi berikutnya adalah diagram batang. Diagram batang cocok digunakan untuk membandingkan data kategorical baik antar waktu maupun antar item data. Kategori yang dibandingkan jumlahnya bisa lebih banyak dibandingkan ketika kita menggunakan pie chart. Sebagai contoh mari kita visualisasikan data pada tabel berikut:
#
# <b>Data Penduduk Jawa, Bali. NTT, dan NTB Tahun 2020</b>
#
# | Propinsi | Jumlah Penduduk |
# | :--- | :--- |
# | Jawa Barat | 49.565.200 |
# | Jawa Tengah | 34.738.200 |
# | Jawa Timur | 39.955.900 |
# | DKI Jakarta | 10.576.400 |
# | DI Yogyakarta | 3.919.200 |
# | Banten | 12.895.300 |
# | Bali | 4.414.400 |
# | Nusa Tenggara Timur | 5.513.400 |
# | Nusa Tenggara Barat | 5.225.900 |

# %%
import matplotlib.pyplot as plt
import numpy as np

propinsi = ['Jawa Barat', 'Jawa Tengah', 'Jawa Timur', 'DKI Jakarta', 'DI Yogyakarta', 'Banten', 'Bali', 'Nusa Tenggara Timur',  'Nusa Tenggara Barat']
jumlah_penduduk = [49565200, 34738200, 39955900, 10576400, 3919200, 12895300, 4414400, 5513400, 5225900]

x_coords = np.arange(len(propinsi))
plt.bar(
    x_coords, 
    jumlah_penduduk, 
    tick_label= propinsi
) 

plt.xticks(rotation=90) 
plt.ylabel('Jumlah Penduduk') 
plt.title('Data Penduduk Jawa, Bali. NTT, dan NTB Tahun 2020') 

plt.show()

# %% [markdown]
# Apabila ingin mengurutkan tampilan visualisasi di diagram batang, kita harus mengurutkan datanya secara manual menggunakan dataframe di pandas karena matplotlib tidak menyediakan fasilitas khusus kebutuhan ini. Berikut contoh kasusnya:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

propinsi = ['Jawa Barat', 'Jawa Tengah', 'Jawa Timur', 'DKI Jakarta', 'DI Yogyakarta', 'Banten', 'Bali', 'Nusa Tenggara Timur',  'Nusa Tenggara Barat']
jumlah_penduduk = [49565200, 34738200, 39955900, 10576400, 3919200, 12895300, 4414400, 5513400, 5225900]

data_penduduk = pd.DataFrame({'Propinsi': propinsi, 'Jumlah Penduduk': jumlah_penduduk}) 
data_penduduk.sort_values(by='Jumlah Penduduk', inplace=True)

x_coords = np.arange(len(propinsi))
plt.bar(
    x_coords, 
    data_penduduk['Jumlah Penduduk'], 
    tick_label= data_penduduk['Propinsi']
) 

plt.xticks(rotation=90) 
plt.ylabel('Jumlah Penduduk') 
plt.title('Data Penduduk Jawa, Bali. NTT, dan NTB Tahun 2020') 

plt.show()

# %% [markdown]
# Dengan tampilan berikut, kita akan lebih mudah dalam memahami data di dalam visualisasinya. Apabila kita ingin mengekspos salah satu elemen data pada diagram batang, kita bisa memanfaatkan parameter ``color``. Berikut contoh penggunaannya:

# %%
warna = ['#0000FF', '#0000FF', '#0000FF', '#0000FF', '#0000FF', '#0000FF', '#0000FF', '#FF0000', '#0000FF']

x_coords = np.arange(len(propinsi))
plt.bar(
    x_coords, 
    data_penduduk['Jumlah Penduduk'], 
    tick_label= data_penduduk['Propinsi'],
    color = warna
) 

plt.xticks(rotation=90) 
plt.ylabel('Jumlah Penduduk') 
plt.title('Data Penduduk Jawa, Bali. NTT, dan NTB Tahun 2020') 

plt.show()

# %% [markdown]
# # Diagram Garis
#
# Diagram garis baik digunakan untuk memvisualisasikan perbandingan suatu nilai (perkembangan) antar waktu. Diagram ini bisa digunakan untuk deret waktu yang panjang atau untuk membandingkan antar kategori dengan item yang terbatas. Sebagai contoh mari kita visualisasikan data berikut:
#
# <b>Data Pencatatan Jumlah Pengunjung Restoran X di tanggal 22 Agustus 2021</b>
#
# Asumsi: Data dicatat mulai dari jam 6 pagi sampai dengan jam 21. Pencatatan data dicatat sekali dalam 1 jam.
#
# 100, 102, 98, 70, 300, 305, 546, 690, 120, 145, 43, 57, 600, 987, 800, 234
#
# Mari kita visualisasikan:

# %%
jam_catat = [x for x in range(6,22)]
jumlah_pengunjung = [100, 102, 98, 70, 300, 305, 546, 690, 120, 145, 43, 57, 600, 987, 800, 234]

plt.plot(
    jam_catat, 
    jumlah_pengunjung
) 

plt.title('Data Jumlah Pengunjung Restoran X di tanggal 22 Agustus 2021') 
plt.ylabel('Jumlah Pengunjung') 
plt.xlabel('Jam Pencatatan') 
plt.show()

# %% [markdown]
# Kita juga bisa menambahkan marker untuk penanda poin. Berikut caranya:

# %%
plt.plot(
    jam_catat, 
    jumlah_pengunjung,
    marker = 'x'
) 

plt.title('Data Jumlah Pengunjung Restoran X di tanggal 22 Agustus 2021') 
plt.ylabel('Jumlah Pengunjung') 
plt.xlabel('Jam Pencatatan') 
plt.show()

# %% [markdown]
# Selain dimanfaatkan untuk melihat perkembangan antar waktu, kita juga bisa menggunakan diagram garis untuk komparasi dengan kategori lain antar waktu. Sebagai contoh, kita mau membandingkan antara angka pengunjung aktual dengan yang kita prediksi berdasarkan hari-hari sebelumnya. Berikut contoh kasusnya:

# %%
jumlah_pengunjung_prediksi = [90, 100, 98, 90, 296, 300, 500, 500, 127, 154, 50, 40, 700, 966, 845, 100]

plt.plot(
    jam_catat, 
    jumlah_pengunjung,
    marker = 'x',
    label = 'Aktual'
) 

plt.plot(
    jam_catat,
    jumlah_pengunjung_prediksi,
    linestyle = '--',
    marker = 'x',
    label = 'Prediksi'
)

plt.legend()
plt.title('Data Jumlah Pengunjung (Aktual dan Prediksi) Restoran X di tanggal 22 Agustus 2021') 
plt.ylabel('Jumlah Pengunjung') 
plt.xlabel('Jam Pencatatan') 
plt.show()

# %% [markdown]
# # Scatter Plot
#
# Scatter plot merupakan bentuk visualisasi yang cocok digunakan untuk menggambarkan keterhubungan antar dua item atau distribusi antar dua item. Scatter plot juga bisa membantu kita dalam menemukan pencilan atau outlier dalam fase pemahaman data dalam ilmu sains data. Sebagai contoh kita mau melihat hubungan antara tinggi badan dan berat badan. Datanya adalah sebagai berikut:
#
# | Nama Orang | Tinggi Badan | Berat Badan |
# | :--- | :--- | :--- |
# | A | 179 | 79 |
# | B | 170 | 70 |
# | C | 175 | 79 |
# | D | 178 | 78 |
# | E | 175 | 77 |
# | F | 175 | 77 |
# | G | 180 | 80 |
# | H | 182 | 80 |
# | I | 179 | 89 |
# | J | 178 | 78 |

# %%
nama = 'A B C D E F G H I J'.split()
tinggi = [179, 170, 175, 178, 175, 175, 180, 182, 179, 178]
berat = [79, 70, 79, 78, 77, 77, 80, 80, 89, 78]

plt.scatter(
    tinggi, 
    berat
) 

plt.title('Distribusi Berat dan Tingi Badan Peserta AKMIL') 
plt.ylabel('Berat Badan') 
plt.xlabel('Tinggi Badan') 

for i, name in enumerate(nama):
    plt.annotate(name, (tinggi[i], berat[i]))

plt.tight_layout()
plt.show()

# %% [markdown]
# Kita bisa melihat bahwa nama ``B`` dan `` I`` memiliki kombinasi berat dan tinggi badan yang sangat berbeda dengan orang lainnya. Bisa saja kita asumsikan di awal bahwa ``B`` dan ``I`` merupakan pencilan. Dibutuhkan metode atau pengolahan lainnya untuk memastikan pencilan akan tetapi dengan visualisasi ini kita mendapatkan informasi awal dengan cepat.
#
# Kita juga bisa melihat distribusi dari dua item yang berbeda. Sebagai contoh kita ingin melihat data berat dan diameter dari jeruk nipis dan Lemon. Berikut contoh kasusnya:

# %%
lemon_diameter = [6.44, 6.87, 7.7, 8.85, 8.15, 9.96, 7.21, 10.04, 10.2, 11.06] 
lemon_weight = [112.05, 114.58, 116.71, 117.4, 128.93, 132.93, 138.92, 145.98, 148.44, 152.81] 

lime_diameter = [6.15, 7.0, 7.0, 7.69, 7.95, 7.51, 10.46, 8.72, 9.53, 10.09] 
lime_weight = [112.76, 125.16, 131.36, 132.41, 138.08, 142.55, 156.86, 158.67, 163.28, 166.74] 

plt.scatter(
    lemon_diameter, 
    lemon_weight,
    color = 'y'
) 

plt.scatter(
    lime_diameter, 
    lime_weight,
    color = 'g'
)

plt.title('Lemon VS. Jeruk Nipis') 
plt.xlabel('Diameter (cm)') 
plt.ylabel('Berat (g)') 

plt.legend(['Lemons', 'Jeruk Nipis'], loc= 'upper left')
plt.show()

# %% [markdown]
# Dengan menggunakan visualisasi ini kita bisa melihat kecenderungan jeruk nipis lebih berat dan sedikit lebih besar diameternya dibandingkan dengan lemon.

# %% [markdown]
# # Heatmap
#
# Heatmap digunakan untuk menemukan keserupaan pada suatu kelompok dan melihat tren yang terjadi. Caranya adalah memanfaatkan color saturation untuk menggambarkan kondisi data pada suatu kelompok. Sebagai contoh, kita akan memvisualisasikan data temperatur pada beberapa kota di Asia. Mari kita coba kode program berikut:
#
# ><b>Catatan:</b> Untuk menggambarkan heatmap, kita akan menggunakan library tambahan bernama ``seaborn``. Silakan lakukan instalasi library tersebut. Library Seaborn akan dibahas lebih lengkap pada topik berikutnya. Seaborn berjalan di atas matplotlib dan menyediakan visualisasi dengan bentuk yang lebih indah.

# %%
import seaborn as sbn
import matplotlib.pyplot as plt

cities = ['Tokyo', 'Delhi', 'Shanghai', 'Sao Paulo', 'Mumbai', 'Mexico City', 'Beijing', 'Osaka', 'Cairo', 'New York', 'Dhaka', 'Karachi'] 
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'] 
temperatures = [ [10, 10, 14, 19, 23, 26, 30, 31, 27, 22, 17, 12], # Tokyo 
                 [20, 24, 30, 37, 40, 39, 35, 34, 34, 33, 28, 22], # Delhi 
                 [ 8, 10, 14, 20, 24, 28, 32, 32, 27, 23, 17, 11], # Shanghai 
                 [29, 29, 28, 27, 23, 23, 23, 25, 25, 26, 27, 28], # Sao Paulo 
                 [31, 32, 33, 33, 34, 32, 30, 30, 31, 34, 34, 32], # Mumbai 
                 [22, 24, 26, 27, 27, 26, 24, 25, 24, 24, 23, 23], # Mexico City 
                 [ 2, 5, 12, 21, 27, 30, 31, 30, 26, 19, 10, 4], # Beijing 
                 [ 9, 10, 14, 20, 25, 28, 32, 33, 29, 23, 18, 12], # Osaka 
                 [19, 21, 24, 29, 33, 35, 35, 35, 34, 30, 25, 21], # Cairo 
                 [ 4, 6, 11, 18, 22, 27, 29, 29, 25, 18, 13, 7], # New York 
                 [25, 29, 32, 33, 33, 32, 32, 32, 32, 31, 29, 26], # Dhaka 
                 [26, 28, 32, 35, 36, 35, 33, 32, 33, 35, 32, 28] # Karachi 
               ]

# %%
sbn.heatmap(temperatures, yticklabels=cities, xticklabels=months)
plt.show()

# %% [markdown]
# Bagaimana cara membacanya? Pertama kita fokus dahulu kepada garis warna yang ada dibagian kanan dari heatmap. Warna gelap menunjukkan suhu yang lebih dingin sedangkan semakin warna menuju warna terang maka suhu akan semakin panas. Sebagai contoh, Delhi di bulan Mei akan bersuhu sangat panas sementar Beijing di bulan Desember akan bersuhu sangat dingin. Kita bisa secara cepat melihat kondisi suhu perbulannya di masing-masing negara.
#
# Akan tetapi, pada kenyataannya kita seringkali menghubungkan warna gelap untuk menunjukkan suhu panas dan sebaliknya. Selain itu juga, sebaiknya kota-kota yang ada disusun berdasarkan urutan posisi berdasarkan latitude dan longitude agar kita bisa mendapatkan informasi sebaran suhu secara lebih informatif. Berikut kode programnya:

# %%
cities = ['New York', 'Beijing', 'Tokyo', 'Osaka', 'Shanghai', 'Cairo', 'Delhi', 'Karachi', 'Dhaka', 'Mexico City', 'Mumbai', 'Sao Paulo'] 
temperatures = [ [ 4, 6, 11, 18, 22, 27, 29, 29, 25, 18, 13, 7], # New York 
                 [ 2, 5, 12, 21, 27, 30, 31, 30, 26, 19, 10, 4], # Beijing 
                 [10, 10, 14, 19, 23, 26, 30, 31, 27, 22, 17, 12], # Tokyo 
                 [ 9, 10, 14, 20, 25, 28, 32, 33, 29, 23, 18, 12], # Osaka
                 [ 8, 10, 14, 20, 24, 28, 32, 32, 27, 23, 17, 11], # Shanghai 
                 [19, 21, 24, 29, 33, 35, 35, 35, 34, 30, 25, 21], # Cairo 
                 [20, 24, 30, 37, 40, 39, 35, 34, 34, 33, 28, 22], # Delhi 
                 [26, 28, 32, 35, 36, 35, 33, 32, 33, 35, 32, 28], # Karachi 
                 [25, 29, 32, 33, 33, 32, 32, 32, 32, 31, 29, 26], # Dhaka 
                 [22, 24, 26, 27, 27, 26, 24, 25, 24, 24, 23, 23], # Mexico City 
                 [31, 32, 33, 33, 34, 32, 30, 30, 31, 34, 34, 32], # Mumbai 
                 [29, 29, 28, 27, 23, 23, 23, 25, 25, 26, 27, 28], # Sao Paulo 
               ]

sbn.heatmap( 
    temperatures, 
    yticklabels=cities, 
    xticklabels=months, 
    cmap='coolwarm', 
)

plt.show()

# %% [markdown]
# Dengan membaca visualisasi ini, bagi seseorang yang suka dengan tempat bersuhu dingin dan ingin pergi liburan, maka orang tersebut bisa memilih untuk liburan ke daerah Shanghai, Osaka, Tokyo, Beijing, atau New York di bulan Januari sampai dengan Maret (awal tahun) atau pada akhir tahun di bulan November dan Desember.

# %% [markdown]
# # Histogram
#
# Histogram merupakan tampilan grafis dari tabulasi frekuensi yang digambarkan dalam bentuk batangan. Tiap batang menunjukkan proporsi frekuensi pada masing-masing deret kategori yang berdampingan dengan interval yang tidak overlapping. Untuk bisa memahaminya, mari kita lihat dataset tentang mobil yang didapatkan dari https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv.

# %%
import pandas as pd
import matplotlib.pyplot as plt

path='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/automobileEDA.csv' 
df = pd.read_csv(path) 
display(df.head())
print('Jumlah record:',df['symboling'].count())

print()
display(df.describe(include = 'all'))
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# Mari kita buat histogram dari kolom ``price``:

# %%
df.hist(column='price', bins=30);
plt.show()

# %% [markdown]
# ><b>Catatan:</b> Parameter ``bins`` menyatakan jumlah kelompok data binning yang digunakan. Data binning digunakan untuk mengelompokkan data yang terlalu tersebar ke dalam kelompok-kelompok interval data agar tidak terjadi efek kesalahan pengamatan kecil.
#
# Dari visualisasi histogram tersebut, maka kita bisa menyimpulkan bahwa data mobil memiliki sebaran yang lebih banyak di harga yang murah dibanding yang mahal. Dalam ilmu statistik, distribusi ini menyerupai distribusi chi kuadrat positif.
#
# Kita juga bisa membuat histogram terhadap suatu atribut berdasarkan suatu grup (hubungannya dengan atribut lainnya). Sebagai contoh kita mau menampilkan histogram dari atribut ``price`` berdasarkan kategori data di atribut ``drive-wheel``. Mari kita coba kode program berikut:

# %%
df.hist(column='price', by='drive-wheels', bins=20);

# agar tidak overlapping
plt.tight_layout()
plt.show()

# %% [markdown]
# Selain itu, kita juga bisa membuat histogram yang memuat lebih dari 1 atribut (atau series). Sebagai contoh kita akan menampilkan histogram untuk atribut:

# %%
display(df[['bore', 'stroke']])
# Out:
#      bore  stroke
# 0    3.47    2.68
# 1    3.47    2.68
# 2    2.68    3.47
# 3    3.19    3.40
# 4    3.19    3.40
# ..    ...     ...
# 196  3.78    3.15
# 197  3.78    3.15
# 198  3.58    2.87
# 199  3.01    3.40
# 200  3.78    3.15
#
# [201 rows x 2 columns]

# %%
df[['bore','stroke']].plot(
    kind='hist', 
    alpha=0.7, 
    bins=30, 
    title='Histogram dari Diameter Mesin dan Putaran Mesin', 
    rot=45, 
    grid=True, 
    figsize=(12,8), 
    fontsize=15, 
    color=['#FF5733', '#5C33FF']
) 

plt.xlabel('Ukuran') 
plt.ylabel("Jumlah Mobil");

# %% [markdown]
# # Korelasi
#
# Korelasi adalah pengukuran yang dilakukan untuk melihat sejauh mana nilai saling ketergantungan antar variabel-variabel data yang ada. Korelasi seringkali diartikan sebagai causation (sebab-akibat) padahal kedua hal itu berbeda. Korelasi tidak menggambarkan fungsi sebab-akibat dalam menyatakan ketergantungan antar variabelnya. Analisis korelasi biasanya digunakan sebagai bentuk data preprocessing ketika akan ekstraksi fitur (kolom data mana saja yang akan digunakan dalam pemodelan apabila bentuk data adalah data terstruktur). Metode yang paling populer dalam menentukan korelasi adalah metode Pearson Correlation.
#
# Pearson menyatakan korelasi antar variabel dengan memberikan nilai antara -1 sampai dengan 1. Penjelasan rentang nilai dari Pearson Correlation dapat dilihat pada tabel berikut:
#
# | Nilai Koefisien | Keterangan |
# | :--- | :--- |
# | Mendekati 1 | Total korelasi linear positif |
# | 0 | Tidak ada korelasi linear. Kedua variabel kemungkinan besar tidak saling mempengaruhi|
# | Mendekati -1 | Total korelasi linear negatif |

# %% [markdown]
# Dalam menghitung nilai korelasi, kita akan diminta menghitung juga nilai P. Nilai P menyatakan probabilitas bahwa antar kedua variabel yang ketergantungan signifikan secara statistik. Semakin kecil nilai P maka semakin tinggi dan semakin yakin bahwa antar item tersebut saling ketergantungan. Jika nilai p sebesar 0.05 (5%) maka 95% nilai korelasi tersebut signifikan. Sebaran nilai P dapat dilihat pada tabel berikut:
#
# | Nilai P | Keterangan |
# | :--- | :--- |
# | < 0.001 | Bukti kuat bahwa korelasi signifikan |
# | < 0.05 | Bukti moderat bahwa korelasi signifikan |
# | < 0.1 | Bukti lemah bahwa korelasi signifikan |
# | > 0.1 | Tidak ada bukti bahwa korelasi signifikan |
#
# Pada topik 10, cara menghitung nilai korelasi antar atribut sudah dijelaskan. Di topik ini, mari kita fokus ke menghtiung nilai P dan memvisualisasikan korelasinya. Mari kita mulai dengan menghitung nilai P. Library yang digunakan untuk menghitung nilai P adalah ``scipy`` di sub module ``stats``. Sebagai contoh kita akan menghitung korelasi dan nilai P untuk atribut ``wheel-base`` dengan ``price``. Berikut kode programnya:

# %%
from scipy import stats

pearson_coef, p_value = stats.pearsonr(df['wheel-base'], df['price']) 
print("Koefisien korelasi person sebesar", pearson_coef, " dengan P-Value dari P =", p_value)
# Out:
# Koefisien korelasi person sebesar 0.584641822265508  dengan P-Value dari P = 8.076488270733218e-20

# %% [markdown]
# Meskipun nilai korelasinya tidak terlalu kuat karena hanya bernilai dekat dengan 0.5 akan tetapi nilai P-nya tinggi sehingga kita bisa simpulkan bahwa ada bukti kuat bahwa korelasinya signifikan. Contoh kedua, kita akan menghitung nilai korelasi dan P untuk atribut ``horsepower`` dengan ``harga``. Berikut kode programnya:

# %%
pearson_coef, p_value = stats.pearsonr(df['horsepower'], df['price']) 
print("Koefisien korelasi person sebesar", pearson_coef, " dengan P-Value dari P =", p_value)
# Out:
# Koefisien korelasi person sebesar 0.8095745670036559  dengan P-Value dari P = 6.369057428260101e-48

# %% [markdown]
# Dari hasil perhitungan, kita bisa menyimpulkan bahwa nilai korelasinya tinggi karena mendekati 1 dan berkorelasi linear secara positif. Selain itu juga kuatnya korelasi didukung dengan bukti kuat bahwa korelasi tersebut signifikan. Dalam artian sederhana, nilai dari atribut ``horsepower`` akan bergerak dengan arah yang sama dengan nilai dari atribut ``price``. Peningkatan nilai dari ``horsepower``akan diikuti dengan peningkatan price akan tetapi tidak dalam hal sebab-akibat.
#
# Setelah menghitung nilai P dan korelasinya, mari kita mulai beranjak ke visualisasinya. Sebelum memvisualisasikan korelasi, kita wajib mengetahui terlebih dahulu tipe data dari masing-masing atribut karena dapat membantu kita dalam menentukan bentuk visualisasi yang tepat. Korelasi biasanya dapat dihitung jika tipe datanya adalah tipe numerik. Mari kita lihat sebaran tipe data untuk data mobil di file csv tersebut:

# %%
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %% [markdown]
# Untuk menghitung nilai korelasi antar atribut yang bertipe ``float64`` atau ``int64``, kit abisa menggunakan fungsi ``corr`` dari dataframe pandas. Berikut contohnya:

# %%
display(df.corr())
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %% [markdown]
# Untuk memvisualisasikan nilai kontinu adalah dengan menggunakan scatter plot dengan garis-garis yang pas. Kita bisa memanfaatkan fungsi ``regplot()`` yang ada pada library ``seaborn``. Sebagai contoh, kita akan memvisualisasikan korelasi antara ``engine-size`` dengan ``price``. Berikut contoh penggunaannya:

# %%
import seaborn as sbn

sbn.regplot(x="engine-size", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 53177.43431028685)

# %% [markdown]
# Dari visualisasi tersebut kita bisa menyimpulkan bahwa saat ``engine-size`` naik maka harga mobil tersebut juga tinggi. Atribut ``engine-size`` berpotensi menjadi prediktor harga. Untuk melihat lebih jelas nilai korelasi untuk kedua atribut ini, kita bisa melakukan slicing pada dataframe. Berikut kode programnya:

# %%
display(df[['engine-size','price']].corr())
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %% [markdown]
# Berikutnya mari kita coba visualisasikan korelasi antar atribut ``highway-mpg`` dengan ``price``. Berikut kode programnya:

# %%
display(df[['highway-mpg','price']].corr())
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %%
sbn.regplot(x="highway-mpg", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='highway-mpg', ylabel='price'>

# %% [markdown]
# Dari visualisasi tersebut, kita bisa menyimpulkan bahwa korelasi antara ``highway-mpg`` dengan ``price`` berkorelasi linear negatif. Saat ``highway-mpg`` naik maka harga mobil tersebut rendah. Atribut ``highway-mpg`` berpotensi menjadi prediktor harga.
#
# Sebagai contoh terakhir, mari kita visualisasikan korelasi antara atribut ``peak-rpm`` dengan ``price``. Berikut kode programnya:

# %%
display(df[['peak-rpm','price']].corr())
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %%
sbn.regplot(x="peak-rpm", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='peak-rpm', ylabel='price'>

# %% [markdown]
# Dari visualisasi tersebut, kit abisa menyimpulkan bahwa ``peak-rpm`` bukan merupakan calon prediktor yang baik untuk memprediksi harga karena garis regresinya mendekati horizontal. Titik-titik data sangat tersebar dan jauh dari garis pas dan itu menunjukkan banyak variabilitas dalam data. Secara sederhana kita bisa mengatakan bahwa kedua atribut berkorelasi linear negatif lemah.

# %%
import numpy as np

korelasi = df.corr(method= 'pearson')

mask = np.zeros_like(korelasi)
mask[np.triu_indices_from(mask)] = True
with sbn.axes_style("white"):
    f, ax = plt.subplots(figsize=(20, 10))
    ax = sbn.heatmap(korelasi, mask=mask, vmax=.3, square=True, cmap= 'coolwarm')

plt.show()

# %% [markdown]
# # Boxplot untuk Visualisasi Variabel Kategori (Tipe Nominal)
#
# Visualisasi berikutnya adalah boxplot. Boxplot biasanya digunakan untuk memvisualisasikan variabel kategori. Variabel kategori statistic adalah variabel yang menggambarkan 'karakteristik' dari unit data, dan dipilih dari sekelompok kategori. Variabel kategori dapat memiliki tipe "objek" atau "int64". Boxplot menggambarkan variable variable statistic seperti quartil 1, median / quartil 2, quartil 3, nilai maksimum, nilai minimum, dan outlier. Untuk menggambarkan boxplot, kita menggunakan fungsi ``boxplot`` di library ``seaborn``. Cara membaca boxplot dapat dilihat pada gambar berikut:
#
# <img src = "https://parameterd.files.wordpress.com/2018/09/box-plot1.png" alt = "cara membaca boxplot">
#
# Sebagai contoh, mari visualisasikan variabel kategori statistik untuk atribut ``body-style`` dan ``price``. Berikut kode programnya:

# %%
import seaborn as sbn

sbn.boxplot(x="body-style", y="price", data=df)
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='price'>

# %% [markdown]
# Dari visualisasi tersebut, kita bisa melihat bahwa distribusi harga antar kategori di atribut ``body-style`` saling tumpang tindih secara signifikan. Hal ini mengakibatkan atribut tersebut kurang baik untuk memprediksi harga.
#
# Kita melihat bahwa distribusi harga antara kategori kendaraan memiliki tumpang tindih yang signifikan, sehingga kategori tidak akan menjadi prediktor harga yang baik.

# %% [markdown]
# # Fungsi describe pandas(Lanjutan)
#
# Kita memang sudah membahas fungsi ``describe()`` pada topik 10. Kita akan membahas beberapa bahasan lanjutan terkait fungsi ini. Apabila sebelumnya kita sudah pernah menggunakan fungsi ``describe()`` tanpa parameter dan dengan parameter ``include = 'all'`` maka kita bisa menggunakan nilai lain dari paramater ``include`` yaitu object. Nilai object akan memunculkan statistik deskriptif dari atribut yang bertipe object. Berikut contoh penggunaannya:

# %%
df.describe(include= 'object')
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %% [markdown]
# Selain menggunakan fungsi ``describe`` yang berlaku pada dataframe, kita juga bisa mengolah statistik per satuan series (1 kolom pada dataframe berbentuk series). Sebagai contoh kita mau menghitung kemunculan setiap kategori data di atribut ``drive-wheels``. Berikut kode programnya:

# %%
df['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %% [markdown]
# Untuk membentuk hasil pengolahan statistik menjadi dalam bentuk dataframe, kita bisa memanggil fungsi ``to_frame()``. Berikut contoh penggunaannya:

# %%
df['drive-wheels'].value_counts().to_frame()
# Out:
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %% [markdown]
# Kita juga bisa menggunakan variabel untuk menampung hasil perhitungan tersebut dan melakukan penamaan ulang terhadap kolom hasil perhitungan. Berikut contoh kode programnya:

# %%
drive_wheels_counts = df['drive-wheels'].value_counts().to_frame() 
drive_wheels_counts.rename(columns={'drive-wheels': 'value_counts'}, inplace=True) 
drive_wheels_counts
# Out:
#      value_counts
# fwd           118
# rwd            75
# 4wd             8

# %% [markdown]
# Mari kita coba untuk kasus pada atribut ``engine-location``. Berikut kode programnya:

# %%
engine_loc_counts = df['engine-location'].value_counts().to_frame() 
engine_loc_counts.rename(columns={'engine-location': 'value_counts'}, inplace=True) 
engine_loc_counts.index.name = 'engine-location' 
engine_loc_counts.head(10)
# Out:
#                  value_counts
# engine-location
# front                     198
# rear                        3

# %% [markdown]
# Dari hasil perhitungan tersebut juga kita bisa menyimpulkan bahwa atribut ``engine-location`` kurang baik digunakan sebagai prediktor karena data kategori ``rear`` hanya bernilai 3 dari 201 data yang ada. Tentunya hal ini menyebabkan ketidakseimbangan jumlah data pada atribut ``engine-location``.

# %% [markdown]
# # Visualisasi Grouping
#
# Seperti pada bahasan sebelumnya tentang pandas, kita bisa mengolah statistik berdasarkan kelompok kategori tertentu di suatu atribut atau lebih. Istilah itu dikenal sebagai grouping (group by). Mari kita lihat proses grouping pada data mobil dari file CSV.
#
# Sebagai contoh, mari kita mencoba meng-grouping data mobil berdasarkan atribut ``drive-wheels``. Berikut kode programnya:
#
# <b>Mengetahui kategori unique yang ada di atribut ``drive-wheels``</b>

# %%
import pandas as pd
import numpy as np

df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %% [markdown]
# Sebagai contoh, kita slicing saja dataframe ``df`` menjadi dataframe yang hanya berisikan ``drive-wheels``, ``body-style``, dan ``price``
#
# <b>Slicing dataframe dan Menghitung rata-rata dari setiap kategori di atribut ``drive-wheels``</b>

# %%
df_group_one = df[['drive-wheels','body-style','price']]
display(df_group_one)

df_group_one = df_group_one.groupby(['drive-wheels'],as_index=False).mean() 
display(df_group_one)
# Out:
#     drive-wheels   body-style    price
# 0            rwd  convertible  13495.0
# 1            rwd  convertible  16500.0
# 2            rwd    hatchback  16500.0
# 3            fwd        sedan  13950.0
# 4            4wd        sedan  17450.0
# ..           ...          ...      ...
# 196          rwd        sedan  16845.0
# 197          rwd        sedan  19045.0
# 198          rwd        sedan  21485.0
# 199          rwd        sedan  22470.0
# 200          rwd        sedan  22625.0
#
# [201 rows x 3 columns]
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %% [markdown]
# Kita juga bisa membuat group yang didasarkan pada dua atribut atau lebih. Berikut contohnya:

# %%
df_gptest = df[['drive-wheels','body-style','price']] 
grouped_test1 = df_gptest.groupby(['drive-wheels','body-style'],as_index=False).mean() 
grouped_test1
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %% [markdown]
# Setelah di-grouping, kita bisa melakukan pivot terhadap  data di ``grouped_test1``. Berikut kode programnya:

# %%
grouped_pivot = grouped_test1.pivot(index='drive-wheels',columns='body-style') 
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# Mari kita tangani missing value dengan mengisikan 0 ke missing value. Berikut kode programnya:

# %%
grouped_pivot = grouped_pivot.fillna(0) #fill missing values with 0 
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# Kita bisa memvisualisasikan data grouping menggunakan heatmap. Berikut kode programnya:

# %%
fig, ax = plt.subplots() 

im = ax.pcolor(grouped_pivot, cmap='RdBu') 

#label names 
row_labels = grouped_pivot.columns.levels[1] 
col_labels = grouped_pivot.index 

#move ticks and labels to the center 
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False) 
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False) 

#insert labels 
ax.set_xticklabels(row_labels, minor=False) 
ax.set_yticklabels(col_labels, minor=False) 

#rotate label if too long plt.xticks(rotation=90) 
fig.colorbar(im) 
plt.show()
